# %%
import numpy as np
import pandas as pd
from numpy.random import randn

from scipy import stats

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([ 3.,  3., 10., 13., 17., 30., 11.,  9.,  2.,  2.]),
#  array([-2.61041544, -2.07080579, -1.53119614, -0.99158649, -0.45197684,
#          0.08763281,  0.62724246,  1.16685212,  1.70646177,  2.24607142,
#          2.78568107]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)

# %%
plt.hist(dataset2, color='indianred')
# Out:
# (array([ 3.,  2., 14., 13., 18.,  7., 13.,  8.,  1.,  1.]),
#  array([-2.25181949, -1.7401575 , -1.22849551, -0.71683352, -0.20517153,
#          0.30649046,  0.81815245,  1.32981444,  1.84147643,  2.35313842,
#          2.86480041]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1, color='indianred', alpha=0.5, bins=20)
plt.hist(dataset2, alpha=0.5, bins=20)
# Out:
# (array([ 2.,  1.,  1.,  1.,  3., 11.,  6.,  7.,  8., 10.,  3.,  4.,  7.,
#          6.,  5.,  3.,  1.,  0.,  0.,  1.]),
#  array([-2.25181949, -1.99598849, -1.7401575 , -1.4843265 , -1.22849551,
#         -0.97266451, -0.71683352, -0.46100252, -0.20517153,  0.05065947,
#          0.30649046,  0.56232146,  0.81815245,  1.07398345,  1.32981444,
#          1.58564544,  1.84147643,  2.09730743,  2.35313842,  2.60896942,
#          2.86480041]),
#  <a list of 20 Patch objects>)

# %%
data1 = randn(1000)
data2 = randn(1000)

# %%
sns.jointplot(data1, data2)

# %%
sns.jointplot(data1, data2, kind='hex')
